# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.boxofficemojo.com/year/2018/?grossesOption=totalGrosses'
response = requests.get(url)

url2 = 'https://en.wikipedia.org/wiki/List_of_female_film_and_television_directors'
response2 = requests.get(url2)

url3 = 'https://www.boxofficemojo.com/release/rl2488436225/?ref_=bo_yld_table_6'
response3 = requests.get(url3)

url4 = 'https://pro.imdb.com/title/tt5463162/filmmakers'
response4 = requests.get(url4)

# %%
page = response.text

# %%
page2 = response2.text

# %%
page3 = response3.text

# %%
page4 = response4.text

# %%
soup3 = BeautifulSoup(page3, "lxml")

# %%
soup4 = BeautifulSoup(page4, "lxml")

# %%
soup = BeautifulSoup(page, "lxml")

# %%
soup2 = BeautifulSoup(page2, "lxml")

# %%
print(soup)

# %%
# Movie titles from Domestic gross 'year' page

titles = soup.find_all('td', class_='a-text-left mojo-field-type-release mojo-cell-wide')

# %%
titles[0].select('a')
# Out:
# [<a class="a-link-normal" href="/release/rl2992866817/?ref_=bo_yld_table_1">Black Panther</a>]

# %%
titles[0].select('a')[0].string
# Out:
# 'Black Panther'

# %%
All_titles = []
for item in titles:
    All_titles.append(item.select('a')[0].string)

# %%
len(All_titles)
# Out:
# 200

# %%
# Movie domestic gross from Domestic gross 'year' page

dtg = soup.find_all('td', class_='a-text-right mojo-field-type-money mojo-estimatable')

# %%
item2 = dtg[0].text[1:]

# %%
item3= int(item2.replace(',',''))
print(item3)
type(item3)
# Out:
# 700059566
# int

# %%
All_dtg = []
for item in dtg:
    item_new  = item.text[1:]
    item_new2 = int(item_new.replace(',',''))
    All_dtg.append(item_new2)

# %%
len(All_dtg)
# Out:
# 200

# %%
soup.find_all("td", class_="a-text-left mojo-field-type-studio")[0].text[0:-3]
# Out:
# 'Walt Disney Studios Motion Picture'

# %%
# Distributor from Domestic gross 'year' page

All_distributor = []
for item in distributor:
    item_new  = item.text[:-3]
    All_distributor.append(item_new)

# %%
len(All_distributor)
# Out:
# 200

# %%
soup.find_all("td", class_="a-text-right mojo-field-type-positive_integer")[0].text
# Out:
# '4,084'

# %%
Max_th = soup.find_all("td", class_="a-text-right mojo-field-type-positive_integer")

# %%
Max_th
# Out:
# [<td class="a-text-right mojo-field-type-positive_integer">4,084</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,020</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,474</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,474</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,410</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,410</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,485</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,475</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,184</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,125</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,349</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,349</td>,
#  <td class="a-text-right mojo-field-type-positive_integer">4,141</td>,
# ...

# %%
All_max_th = []
for item in Max_th:
    item_new = item.text.replace(',','')
    All_max_th.append(item_new)

# %%
All_max_th
# Out:
# ['4084',
#  '4020',
#  '4474',
#  '4474',
#  '4410',
#  '4410',
#  '4485',
#  '4475',
#  '4184',
#  '4125',
#  '4349',
#  '4349',
#  '4141',
#  '4141',
#  '4395',
#  '4386',
#  '4206',
#  '4206',
#  '4000',
#  '4000',
#  '3904',
#  '3686',
#  '4381',
#  '4381',
#  '4250',
#  '4250',
#  '4017',
#  '4017',
#  '3813',
#  '3813',
#  '3808',
#  '3508',
#  '3865',
#  '3384',
#  '4090',
#  '4090',
#  '4267',
#  '4267',
#  '4163',
#  '4163',
#  '3990',
#  '3928',
#  '4118',
#  '4118',
#  '4145',
#  '4145',
#  '4234',
#  '4234',
#  '3597',
#  '3550',
#  '3514',
#  '3317',
#  '3876',
#  '3876',
#  '3752',
#  '3441',
#  '3725',
#  '3725',
#  '3329',
#  '2588',
#  '3388',
#  '3388',
#  '4115',
#  '4101',
#  '3980',
#  '3980',
#  '3768',
#  '3768',
#  '3602',
#  '3602',
#  '2648',
#  '25',
#  '2894',
#  '1629',
#  '4131',
#  '4131',
#  '3019',
#  '3010',
#  '3038',
#  '3031',
#  '3502',
#  '3488',
#  '3169',
#  '2781',
#  '3592',
#  '3592',
#  '3822',
#  '3782',
#  '3150',
#  '3116',
#  '3426',
# ...

# %%
year = soup.find_all('h1', class_="mojo-gutter")[0].text[-4:]

# %%
year
# Out:
# '2018'

# %%
All_date_rel = []
for item in Date_rel:
    All_date_rel.append(item.text)

# %%
len(All_date_rel)
# Out:
# 200

# %%
All_date_rel = All_date_rel[0::2]

# %%
All_date_rel
# Out:
# ['Feb 16',
#  'Apr 27',
#  'Jun 15',
#  'Jun 22',
#  'Dec 21',
#  'May 18',
#  'Nov 9',
#  'Jul 27',
#  'Jul 6',
#  'Nov 2',
#  'Oct 5',
#  'May 25',
#  'Oct 5',
#  'Nov 21',
#  'Dec 14',
#  'Apr 6',
#  'Aug 15',
#  'Dec 19',
#  'Jul 13',
#  'Nov 16',
#  'Oct 19',
#  'Aug 10',
#  'Jun 8',
#  'Mar 29',
#  'Dec 21',
#  'Jul 20',
#  'Sep 7',
#  'Nov 21',
#  'Feb 9',
#  'Dec 14',
#  'Jul 20',
#  'Apr 13',
#  'Mar 9',
#  'Feb 9',
#  'Aug 3',
#  'Nov 16',
#  'Mar 16',
#  'Sep 28',
#  'Sep 28',
#  'Jul 4',
#  'Feb 23',
#  'May 18',
#  'Sep 21',
#  'Jul 13',
#  'Jan 5',
#  'Nov 16',
#  'Apr 6',
#  'Mar 23',
#  'Mar 16',
#  'Jan 26',
#  'Nov 2',
#  'Jun 15',
#  'Sep 14',
#  'May 11',
#  'Sep 14',
#  'May 4',
#  'Jun 29',
#  'Aug 10',
#  'Apr 20',
#  'Dec 25',
#  'Mar 2',
#  'May 11',
#  'Oct 12',
#  'Jan 19',
#  'Jan 19',
#  'Oct 12',
#  'Jun 8',
#  'Mar 30',
#  'Mar 23',
#  'Jun 29',
#  'Nov 16',
#  'Apr 13',
#  'Jan 12',
#  'Mar 16',
#  'Dec 21',
#  'Jan 12',
#  'Feb 9',
#  'Aug 17',
# ...

# %%
my_new_list = [ x + ", " + year for x in All_date_rel]

# %%
my_new_list
# Out:
# ['Feb 16, 2018',
#  'Aug 9, 2018',
#  'Apr 27, 2018',
#  'Sep 13, 2018',
#  'Jun 15, 2018',
#  'Dec 13, 2018',
#  'Jun 22, 2018',
#  'Oct 4, 2018',
#  'Dec 21, 2018',
#  'Apr 4, 2018',
#  'May 18, 2018',
#  'Oct 18, 2018',
#  'Nov 9, 2018',
#  'Feb 14, 2018',
#  'Jul 27, 2018',
#  'Oct 18, 2018',
#  'Jul 6, 2018',
#  'Nov 1, 2018',
#  'Nov 2, 2018',
#  'Apr 25, 2018',
#  'Oct 5, 2018',
#  'Apr 4, 2018',
#  'May 25, 2018',
#  'Sep 20, 2018',
#  'Oct 5, 2018',
#  'Jan 24, 2018',
#  'Nov 21, 2018',
#  'Apr 11, 2018',
#  'Dec 14, 2018',
#  'Apr 4, 2018',
#  'Apr 6, 2018',
#  'Aug 2, 2018',
#  'Aug 15, 2018',
#  'Jan 10, 2018',
#  'Dec 19, 2018',
#  'Apr 11, 2018',
#  'Jul 13, 2018',
#  'Nov 29, 2018',
#  'Nov 16, 2018',
#  'Feb 21, 2018',
#  'Oct 19, 2018',
#  'Jan 3, 2018',
#  'Aug 10, 2018',
#  'Nov 1, 2018',
#  'Jun 8, 2018',
#  'Sep 20, 2018',
#  'Mar 29, 2018',
#  'Jul 5, 2018',
#  'Dec 21, 2018',
#  'Mar 7, 2018',
#  'Jul 20, 2018',
#  'Oct 11, 2018',
#  'Sep 7, 2018',
# ...

# %%
# Now scrape information from a movie's website

# %%
import re
runtime_regex = re.compile('Run')
soup3.find(text=runtime_regex)
# Out:
# 'Running Time'

# %%
rt_string = soup3.find(text=re.compile('Run'))

# %%
rt_string.findNext()
# Out:
# <span>1 hr 59 min</span>

# %%
rt = rt_string.findNext().text
rt = rt.split()
minutes = int(rt[0])*60 + int(rt[2])
print(minutes)
# Out:
# 119

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
def get_movie_value_op(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find_all(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
rating = get_movie_value(soup3,'MPAA')
print(rating)
# Out:
# R

# %%
release_date = get_movie_value(soup3,'Release Date')
print(release_date)
# Out:
# May 18, 2018
#             -
#             Oct 18, 2018

# %%
release_date = release_date.split('\n')[0]  #Select the only the date
print(release_date)
# Out:
# May 18, 2018

# %%
runtime_regex2 = re.compile('Budget')
soup3.find(text=runtime_regex2)
# Out:
# 'Budget'

# %%
rt_string2 = soup3.find(text=re.compile('Budget'))

# %%
rt_string2.findNext().text
# Out:
# '$110,000,000'

# %%
runtime_regex3 = re.compile('Genres')
soup3.find_all(text=runtime_regex3)
# Out:
# ['Genres']

# %%
rt_string3 = soup3.find(text=re.compile('Genres'))

# %%
rt_string3.findNext().text.split('\n')
# Out:
# ['Action',
#  '    ',
#  '        Adventure',
#  '    ',
#  '        Comedy',
#  '    ',
#  '        Sci-Fi']

# %%
soup4
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="a-no-js a-lt-ie10 a-lt-ie9 a-ie8" data-19ax5a9jf="dingo"><![endif]--><!--[if IE 9]><html class="a-no-js a-lt-ie10 a-ie9" data-19ax5a9jf="dingo"><![endif]--><!--[if !IE]><!--><html class="a-no-js" data-19ax5a9jf="dingo"><!--<![endif]--><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><script data-a-state='{"key": "csm"}' type="a-state">
# {"pageType": "title", "subpageType": "v2_cast_public"}
# </script>
# <meta content="See Deadpool 2's production, company, and contact information. Explore Deadpool 2's box office performance, follow development, and track popularity with MOVIEmeter. IMDbPro — The essential resource for entertainment professionals." name="description"/>
# <meta content="https://m.media-amazon.com/images/M/MV5BNjk1Njk3YjctMmMyYS00Y2I4LThhMzktN2U0MTMyZTFlYWQ5XkEyXkFqcGdeQXVyODM2ODEzMDA@._V1_.jpg" property="og:image"/>
# ...

# %%
runtime_regex4 = re.compile('Director')
soup4.find_all(text=runtime_regex4)[1]
# Out:
# ' Director'

# %%
rt_string4 = soup4.find(text=re.compile('Director'))

# %%
rt_string4.findNext()
# Out:
# <li>
# <a href="https://pro.imdb.com/discover/people?profession=writer&amp;ref_=tt_pub_nv_ppl_wrt"> Writers
# </a> </li>

# %% [markdown]
# # Female directors' list from Wikipedia

# %%
# Let's move to create the female directors' list, data from Wikipedia 
soup2
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of female film and television directors - Wikipedia</title>
# ...

# %%
Fem_directors = soup2.find_all('div', class_="div-col")

# %%
All_fem_dir_raw =[]
for item in Fem_directors:
    item_new = item.text
    item_new2 = item_new.split('\n')
    All_fem_dir_raw.extend(item_new2[1:-1])

# %%
Fem_directors = soup2.find_all('div', class_="div-col")

# %%
All_fem_dir_raw
# Out:
# ['Jennifer Abbott (Canada)',
#  'Jennifer Abod (USA)',
#  'Marguerite Abouet (Ivory Coast)',
#  'Abiola Abrams (USA)',
#  'Ally Acker (USA)',
#  'Jill Ackles (USA)',
#  'Kasia Adamik (Poland)',
#  'Catlin Adams (USA)',
#  'Joey Lauren Adams (USA)',
#  'Perry Miller Adato (USA)',
#  'Anita W. Addison (USA)',
#  'Maren Ade (Germany)',
#  'Elvire Adjamonsi (Benin)',
#  'Dianna Agron (USA)',
#  'Yasmin Ahmad (Malaysia)',
#  'Peggy Ahwesh (USA)',
#  'Shirikiana Aina (USA)',
#  'Kyōko Aizome (Japan)',
#  'Mania Akbari (Iran)',
#  'Chantal Akerman (Belgium-France)',
#  'Desiree Akhavan (USA)',
#  'Zoya Akhtar  (India)',
#  'Nargis Akhter (Bangladesh)',
#  'Haifaa al-Mansour (Saudi Arabia)',
#  'Gina Alajar (Philippines)',
#  'Barbara Albert (Austria)',
#  'Karin Albou (France)',
#  'Victoria Aleksanyan (Armenia)',
#  'Lexi Alexander (USA)',
#  'Debbie Allen (USA)',
#  'Elizabeth Allen (USA)',
#  'Jennifer Alleyn (Canada)',
#  'Natalia Almada (Mexico-USA)',
#  'Chihiro Amano (Japan)',
# ...

# %%
len(All_fem_dir_raw)
# Out:
# 1364

# %%
All_fem_dir =[]
for item in All_fem_dir_raw:
    if "(" in item:
        for c in item:
            if c == '(':
                index= item.index(c)
                item_new = item.replace(item[index-1:],'')
                All_fem_dir.append(item_new)
    else:
        All_fem_dir.append(item)

# %%
len(All_fem_dir)
# Out:
# 1369

# %%
for item in All_fem_dir:
    if All_fem_dir.count(item) == 2:
        print (item)
# Out:
# Dorothy Davenport
# Dorothy Davenport
# Kim Friedman
# Kim Friedman
# Li Yu
# Li Yu
# Lucile McVey
# Lucile McVey
# Francine Pelletier
# Francine Pelletier
# Jeanne Roques
# Jeanne Roques

# %%
All_fem_dir.remove('Dorothy Davenport')
All_fem_dir.remove('Kim Friedman')
All_fem_dir.remove('Li Yu')
All_fem_dir.remove('Lucile McVey')
All_fem_dir.remove('Francine Pelletier')
All_fem_dir.remove('Jeanne Roques')

# %%
len(All_fem_dir)
# Out:
# 1363

# %% [markdown]
# # Automated Data Scraping

# %%
# Now let's build the structure of the data collection. 
# First we will create a list which includes all movies title and link of their pages. Store in a dictionary
# Secondly write a code which accesses to the movies' website and let us scrape information from there

# %%
rows = [row for row in soup.find_all('tr')]

# %%
# Create a list with the links of the years of the movies we want to use 2001-2021

year_list = ['https://www.boxofficemojo.com/year/2001/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2002/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2003/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2004/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2005/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2006/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2007/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2008/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2009/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2010/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2011/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2012/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2013/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2014/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2015/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2016/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2017/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2018/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2019/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2020/?grossesOption=totalGrosses',
            'https://www.boxofficemojo.com/year/2021/?grossesOption=totalGrosses',]

# %%
len(year_list)
# Out:
# 21

# %%
# Create a function that will create a soup for the link of years what we can use to get the movies name and links for each year

# Test on 2 years

link_of_years4_test = year_list[1:2]
full_rows_test = []
movies_test = {}

for item in link_of_years4_test:
    url7 = item
    response7 = requests.get(url6)
    print(response7.status_code)
    page7 = response7.text
    soup7 = BeautifulSoup(page7, "lxml")
    
    rows = [row for row in soup7.find_all('tr')]
    full_rows_test.append(rows)
    
    for row in rows[1:10]:
        items = row.find_all('td')
        link = items[1].find('a')
        title, url = link.text, link['href']
        movies_test[title] = url
        

print(len(movies_test))
# Out:
# 200
# 9

# %%
movies_test
# Out:
# {'Godzilla vs. Kong': '/release/rl1383892481/?ref_=bo_yld_table_1',
#  'A Quiet Place Part II': '/release/rl2819065345/?ref_=bo_yld_table_2',
#  'Raya and the Last Dragon': '/release/rl3781723649/?ref_=bo_yld_table_3',
#  'Demon Slayer: Mugen Train': '/release/rl3648226049/?ref_=bo_yld_table_4',
#  'Tom and Jerry': '/release/rl2399766017/?ref_=bo_yld_table_5',
#  'Cruella': '/release/rl3708126721/?ref_=bo_yld_table_6',
#  'Mortal Kombat': '/release/rl1862829569/?ref_=bo_yld_table_7',
#  'Nobody': '/release/rl604276225/?ref_=bo_yld_table_8',
#  'Wrath of Man': '/release/rl2976809729/?ref_=bo_yld_table_9'}

# %%
# Create a list of dictionaries with all the movies and their links

link_of_years4 = year_list
full_rows = []
movies = {}

for item in link_of_years4:
    url6 = item
    response6 = requests.get(url6)
    print(response6.status_code)
    page6 = response6.text
    soup6 = BeautifulSoup(page6, "lxml")
    
    # get the link of the movies
    
    rows = [row for row in soup6.find_all('tr')]
    full_rows.append(rows)
    
    for row in rows[1:]:
        items = row.find_all('td')
        link = items[1].find('a')
        title, url = link.text, link['href']
        movies[title] = url
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len(movies)
# Out:
# 4071

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    try:
        obj = soup.find(text=re.compile(field_name))
    
        if not obj: 
            return None
    
        # this works for most of the values
        next_element = obj.findNext()
    
        if next_element:
            return next_element.text 
        else:
            return None
    except:
        return None

# %%
def get_movie_opening(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    try:
        obj = soup.find(text=re.compile(field_name))
    
        if not obj: 
            return None
    
    # this works for most of the values
        next_element = obj.findNext()
        next_element = next_element.find(class_='money')
    
        if next_element:
            return next_element.text
        else:
            return None
    except:
        return None

# %%
def get_movie_max_theatre(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    try:
        obj = soup.find(text=re.compile(field_name))
    
        if not obj: 
            return None
    
    # this works for most of the values
        next_element = obj.findNext()
        next_element = next_element.split()[0]
    
        if next_element:
            return next_element.text
        else:
            return None
    except:
        return None

# %%
# Helper funtions

import dateutil.parser

def money_to_int(moneystring):
    try:
        moneystring = moneystring.replace('$', '').replace(',', '')
        return int(moneystring)
    except:
        return None

def runtime_to_minutes(runtimestring):
    try:
        runtime = runtimestring.split()
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    try:
        date = dateutil.parser.parse(datestring)
        return date
    except:
        return None

# %%
#now lets make a function that grabs the links of the movies and let us access data on the movie's page

#final version

movie_data = []


for key in movies:
    
    movies_dict = {}
    
    base_url = 'https://www.boxofficemojo.com'
    url_movie_fin = (base_url + movies[key])
    response_movie_fin = requests.get(url_movie_fin)

    page_fin = response_movie_fin.text
    soup_fin = BeautifulSoup(page_fin, "lxml")

# Titles
    movies_dict['Title'] = key


# Domestic gross
    dtg = soup_fin.find(class_='mojo-performance-summary-table').find_all('span', class_='money')[0].text
    raw_domestic_total_gross = dtg
    domestic_total_gross = money_to_int(raw_domestic_total_gross)
    movies_dict['domestic_gross'] = domestic_total_gross


# International gross
    intg = soup_fin.find(class_='mojo-performance-summary-table').find_all('span', class_='money')[1].text
    raw_internation_gross = intg
    international_total_gross = money_to_int(raw_internation_gross)
    movies_dict['international_gross'] = international_total_gross

# Opening weekend gross
    obj = get_movie_opening(soup_fin, 'Opening')
    opening = money_to_int(next_element.text)
    movies_dict['op_weekend_gr'] = opening
    

# Running time
    raw_runtime = get_movie_value(soup_fin,'Running')
    runtime = runtime_to_minutes(raw_runtime)
    movies_dict['running_time'] = runtime

# Release date
    raw_release_date = get_movie_value(soup_fin,'Release Date').split('\n')[0]
    release_date = to_date(raw_release_date)
    movies_dict['release_date'] = release_date

# MPAA ratings
    rating = get_movie_value(soup_fin,'MPAA')
    movies_dict['MPAA'] = rating

# Max theatre
    max_theatre = get_movie_max_theatre(soup_fin,'Widest')
    max_theatre = money_to_int(max_theatre)
    movies_dict['max_theatre'] = max_theatre


# Distributor
    distributor = get_movie_value(soup_fin,'Distributor')
    movies_dict['distributor'] = distributor

# In release
    in_release = get_movie_value(soup_fin,'In Release')
    movies_dict['in_release_days'] = in_release

# Genre
    genre = get_movie_value(soup_fin,'Genres')
    movies_dict['genres'] = genre


# Budget
    
    raw_budget = get_movie_value(soup_fin,'Budget')
    budget = money_to_int(raw_budget)
    movies_dict['budget'] = budget



    links = []

    for div in soup_fin.find_all('div', class_='a-box-inner'):
        for link in div.find_all('a'):
            links.append(link.get("href"))

        
    url_movie_fin = links[4]       
    response_movie_fin = requests.get(url_movie_fin)

    page_fin2 = response_movie_fin.text
    soup_fin2 = BeautifulSoup(page_fin2, "lxml")

    # Director

    for div in soup_fin2.find_all('div', id='director_summary'):
        for link in div.find_all('a'):
            movies_dict['director'] = ((f'{link.text}')[:-1]).strip()

    
    movie_data.append(movies_dict)
            
len(movie_data)
# Out:
# 4071

# %%
import pandas as pd

# %%
movies_page_info = pd.DataFrame(movie_data)  #convert list of dict to df
movies_page_info.set_index('Title', inplace=True)

movies_page_info
# Out:
#                                                    domestic_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                   317575550
# The Lord of the Rings: The Fellowship of the Ring          166000
# Shrek                                                   267665011
# Monsters, Inc.                                             726000
# Rush Hour 2                                             226164286
# ...                                                           ...
# The Unthinkable                                               974
# Elbow Grease                                                  917
# First Signal                                                  750
# Sol                                                           543
# Funhouse                                                      507
#
#                                                    international_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                        657179821
# ...

# %%
movies_page_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4071 entries, Harry Potter and the Sorcerer's Stone to Funhouse
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   domestic_gross       4071 non-null   int64
#  1   international_gross  4071 non-null   int64
#  2   op_weekend_gr        4071 non-null   int64
#  3   running_time         3969 non-null   float64
#  4   release_date         3722 non-null   datetime64[ns]
#  5   MPAA                 3694 non-null   object
#  6   max_theatre          0 non-null      object
#  7   distributor          4071 non-null   object
#  8   in_release_days      4070 non-null   object
#  9   genres               4063 non-null   object
#  10  budget               2306 non-null   float64
#  11  director             4054 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 413.5+ KB

# %%
movies_page_info.to_csv (r'/Users/gabriellanemeth/Documents/METIS/Reg_course_project_local/movies_dataframe.csv', header=True)

# %%
movies_page_info_test = movies_page_info.copy()

# %%
def in_release_days_fix(item):
    if item != None:
        item = item.split('/')[0].replace(',','')
        item = item.split()[0]
        return int(item)
    else:
        return 0

# %%
movies_page_info['in_release_days'] = movies_page_info['in_release_days'].apply(in_release_days_fix)

# %%
def distributor_fix(item):
    if item != None:
        item = item[:-30]
        return item

# %%
movies_page_info['distributor'] = movies_page_info['distributor'].apply(distributor_fix)

# %%
def genres_fix(item):
    if item != None:
        item = item.replace(' ','')
        item = item.split('\n')
        for c in item:
            if c=='':
                item.remove(c)
        return item
    else:
        return 0

# %%
movies_page_info['genres'] = movies_page_info['genres'].apply(genres_fix)

# %%
movies_page_info.head()
# Out:
#                                                    domestic_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                   317575550
# The Lord of the Rings: The Fellowship of the Ring          166000
# Shrek                                                   267665011
# Monsters, Inc.                                             726000
# Rush Hour 2                                             226164286
#
#                                                    international_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                        657179821
# The Lord of the Rings: The Fellowship of the Ring               326266
# Shrek                                                        216744207
# Monsters, Inc.                                                  726000
# Rush Hour 2                                                  121161516
#
#                                                    op_weekend_gr  \
# Title
# ...

# %%
len(movies)
# Out:
# 4071

# %%
movie_data_fix = []

    
for key in movies:
    
    movies_dict_fix = {}
    
    base_url = 'https://www.boxofficemojo.com'
    url_movie_fix = (base_url + movies[key])
    response_movie_fix = requests.get(url_movie_fix)

    page_fix = response_movie_fix.text
    soup_fix = BeautifulSoup(page_fix, "lxml")
    
# Titles
    movies_dict_fix['Title'] = key

# Opening weekend gross, Max theatre
    try:
        obj = soup_fix.find(text=re.compile("Opening"))
        sentence = str(obj.findNext())
        movies_dict_fix['owg_and_max_theatre'] = sentence

        movie_data_fix.append(movies_dict_fix)
        
    except:
        movies_dict_fix['owg_and_max_theatre'] = 0

len(movie_data_fix)
# Out:
# 3995

# %%
movie_data_fix
# Out:
# [{'Title': "Harry Potter and the Sorcerer's Stone",
#   'owg_and_max_theatre': '<span><span class="money">$90,294,621</span><br/>3,672\n            theaters</span>'},
#  {'Title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'owg_and_max_theatre': '<span><span class="money">$166,000</span><br/>150\n            theaters</span>'},
#  {'Title': 'Shrek',
#   'owg_and_max_theatre': '<span><span class="money">$42,347,760</span><br/>3,587\n            theaters</span>'},
#  {'Title': 'Monsters, Inc.',
#   'owg_and_max_theatre': '<span><span class="money">$494,000</span><br/>1,875\n            theaters</span>'},
#  {'Title': 'Rush Hour 2',
#   'owg_and_max_theatre': '<span><span class="money">$67,408,222</span><br/>3,118\n            theaters</span>'},
#  {'Title': 'The Mummy Returns',
#   'owg_and_max_theatre': '<span><span class="money">$68,139,035</span><br/>3,401\n            theaters</span>'},
#  {'Title': 'Pearl Harbor',
# ...

# %%
movies_page_info_extra = pd.DataFrame(movie_data_fix)  #convert list of dict to df
movies_page_info_extra.set_index('Title', inplace=True)

movies_page_info_extra
# Out:
#                                                                                  owg_and_max_theatre
# Title
# Harry Potter and the Sorcerer's Stone              <span><span class="money">$90,294,621</span><b...
# The Lord of the Rings: The Fellowship of the Ring  <span><span class="money">$166,000</span><br/>...
# Shrek                                              <span><span class="money">$42,347,760</span><b...
# Monsters, Inc.                                     <span><span class="money">$494,000</span><br/>...
# Rush Hour 2                                        <span><span class="money">$67,408,222</span><b...
# ...                                                                                              ...
# A Glitch in the Matrix                             <span><span class="money">$1,667</span><br/>19...
# Skyfire                                            <span><span class="money">$861</span><br/>2\n ...
# ...

# %%
movies_page_info_extra_test = movies_page_info_extra.copy()

# %%
def fix_owg_max_theatre(text):
    try:
        sentence = text.replace(',','')
        s = [float(s) for s in re.findall(r'-?\d+\.?\d*', sentence)]
        opening = s[0]
        if s[0] == s[1]:
            theatre = 0
        else:
            theatre = s[-1]
        return opening, theatre
    except:
        return 0

# %%
movies_page_info_extra_test['owg'] = owg_and_max_theatre

# %%
def export_theatre(text):
    try:
        if len(text)==2:
            return text[1]
        else:
            return 0
    except:
        return text

# %%
def amend_owg(text):
    try:
        if len(text)==2:
            return text[0]
        else:
            return 0
    except:
        return text

# %%
movies_page_info_extra['owg_and_max_theatre'] = movies_page_info_extra['owg_and_max_theatre'].apply(fix_owg_max_theatre)

# %%
movies_page_info_extra['theatre'] = movies_page_info_extra['owg_and_max_theatre'].apply(export_theatre)

# %%
movies_page_info_extra['owg_and_max_theatre'] = movies_page_info_extra['owg_and_max_theatre'].apply(amend_owg)

# %%
movies_page_info_extra = movies_page_info_extra.rename(columns={"owg_and_max_theatre": "Op_weekend_gr"})

# %%
movies_page_info = movies_page_info.merge(movies_page_info_extra, how='left', on='Title')

# %%
movies_page_info = movies_page_info.drop(['op_weekend_gr', 'max_theatre'], axis=1)

# %%
# Let's add the female directors list to the main dataframe


def female_director(text):
    try:
        if text in All_fem_dir:
            return 1
        else:
            return 0
    except:
        return None

# %%
movies_page_info['director_gender'] = movies_page_info['director'].apply(female_director)

# %%
movies_page_info.head(5)
# Out:
#                                                    domestic_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                   317575550
# The Lord of the Rings: The Fellowship of the Ring          166000
# Shrek                                                   267665011
# Monsters, Inc.                                             726000
# Rush Hour 2                                             226164286
#
#                                                    international_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                        657179821
# The Lord of the Rings: The Fellowship of the Ring               326266
# Shrek                                                        216744207
# Monsters, Inc.                                                  726000
# Rush Hour 2                                                  121161516
#
#                                                    running_time release_date  \
# Title
# ...

# %%
movies_page_info.director_gender.sum()
# Out:
# 221

# %%
All_fem_dir

# %%
movies_page_info.to_csv (r'/Users/gabriellanemeth/Documents/METIS/Reg_course_project_local/movies_dataframe.csv', header=True)

# %%
movies_page_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4071 entries, Harry Potter and the Sorcerer's Stone to Funhouse
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   domestic_gross       4071 non-null   int64
#  1   international_gross  4071 non-null   int64
#  2   running_time         3969 non-null   float64
#  3   release_date         3722 non-null   datetime64[ns]
#  4   MPAA                 3694 non-null   object
#  5   distributor          4071 non-null   object
#  6   in_release_days      4071 non-null   int64
#  7   genres               4071 non-null   object
#  8   budget               2306 non-null   float64
#  9   director             4054 non-null   object
#  10  Op_weekend_gr        3995 non-null   float64
#  11  theatre              3995 non-null   float64
#  12  director_gender      4071 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(4)
# ...

# %%
movies_page_info_test.loc["Lottery Ticket"]
# Out:
# domestic_gross                    24719879
# international_gross                      0
# op_weekend_gr                        53058
# running_time                            99
# release_date           2010-08-20 00:00:00
# MPAA                                 PG-13
# max_theatre                           None
# distributor                   Warner Bros.
# in_release_days                        134
# genres                            [Comedy]
# budget                             1.7e+07
# director                        Erik White
# director_gender                          0
# Name: Lottery Ticket, dtype: object

# %%
import numpy as np

# %%
movies_page_info['international_gross'] = np.where(movies_page_info['international_gross']== movies_page_info['domestic_gross'], 0, movies_page_info['international_gross'])

# %%
movies_page_info['total_gross'] = movies_page_info['international_gross'] + movies_page_info['domestic_gross']

# %%
movies_page_info
# Out:
#                                                    domestic_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                   317575550
# The Lord of the Rings: The Fellowship of the Ring          166000
# Shrek                                                   267665011
# Monsters, Inc.                                             726000
# Rush Hour 2                                             226164286
# ...                                                           ...
# The Unthinkable                                               974
# Elbow Grease                                                  917
# First Signal                                                  750
# Sol                                                           543
# Funhouse                                                      507
#
#                                                    international_gross  \
# Title
# Harry Potter and the Sorcerer's Stone                        657179821
# ...
